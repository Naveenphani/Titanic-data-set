# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('All_Indian_Trains.csv')
data
# Out:
#       Unnamed: 0  Train no.                     Train name  \
# 0              0      12723         Andhra Pradesh Express
# 1              1      22416         Andhra Pradesh Express
# 2              2      12724         Andhra Pradesh Express
# 3              3      12707  Andhra Pradesh Sampark Kranti
# 4              4      15909            Abadh Assam Express
# ...          ...        ...                            ...
# 4019         218      12551              Yprkyq Ac Express
# 4020         219       2651                 Yprkyq Express
# 4021         220       2551                 Yprkyq Express
# 4022         221      12395                Ziyarat Express
# 4023         222      12396                Ziyarat Express
#
#                      Starts                Ends
# 0           Hyderabad Decan           New Delhi
# 1                 New Delhi       Vishakapatnam
# 2                 New Delhi     Hyderabad Decan
# 3                  Tirupati        H Nizamuddin
# ...

# %%
data.shape
# Out:
# (4024, 5)

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# Train no.     0
# Train name    0
# Starts        0
# Ends          0
# dtype: int64

# %%
data.describe()
# Out:
#         Unnamed: 0     Train no.
# count  4024.000000   4024.000000
# mean    454.616302  14655.801690
# std     279.980977  11555.820993
# min       0.000000    111.000000
# 25%     201.000000   8620.250000
# 50%     447.000000  12720.500000
# 75%     698.000000  17210.250000
# max     966.000000  99734.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4024 non-null   int64
#  1   Train no.   4024 non-null   int64
#  2   Train name  4024 non-null   object
#  3   Starts      4024 non-null   object
#  4   Ends        4024 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 157.3+ KB

# %%
data.dtypes
# Out:
# Unnamed: 0     int64
# Train no.      int64
# Train name    object
# Starts        object
# Ends          object
# dtype: object

# %%
data
# Out:
#       Unnamed: 0  Train no.                     Train name  \
# 0              0      12723         Andhra Pradesh Express
# 1              1      22416         Andhra Pradesh Express
# 2              2      12724         Andhra Pradesh Express
# 3              3      12707  Andhra Pradesh Sampark Kranti
# 4              4      15909            Abadh Assam Express
# ...          ...        ...                            ...
# 4019         218      12551              Yprkyq Ac Express
# 4020         219       2651                 Yprkyq Express
# 4021         220       2551                 Yprkyq Express
# 4022         221      12395                Ziyarat Express
# 4023         222      12396                Ziyarat Express
#
#                      Starts                Ends
# 0           Hyderabad Decan           New Delhi
# 1                 New Delhi       Vishakapatnam
# 2                 New Delhi     Hyderabad Decan
# 3                  Tirupati        H Nizamuddin
# ...

# %%
data=data.drop(['Ends'],axis=1)
data
# Out:
#       Unnamed: 0  Train no.                     Train name  \
# 0              0      12723         Andhra Pradesh Express
# 1              1      22416         Andhra Pradesh Express
# 2              2      12724         Andhra Pradesh Express
# 3              3      12707  Andhra Pradesh Sampark Kranti
# 4              4      15909            Abadh Assam Express
# ...          ...        ...                            ...
# 4019         218      12551              Yprkyq Ac Express
# 4020         219       2651                 Yprkyq Express
# 4021         220       2551                 Yprkyq Express
# 4022         221      12395                Ziyarat Express
# 4023         222      12396                Ziyarat Express
#
#                      Starts
# 0           Hyderabad Decan
# 1                 New Delhi
# 2                 New Delhi
# 3                  Tirupati
# 4     New Tinsukia Junction
# ...                     ...
# 4019    Yesvantpur Junction
# ...

# %%
data
# Out:
#       Unnamed: 0  Train no.                     Train name  \
# 0              0      12723         Andhra Pradesh Express
# 1              1      22416         Andhra Pradesh Express
# 2              2      12724         Andhra Pradesh Express
# 3              3      12707  Andhra Pradesh Sampark Kranti
# 4              4      15909            Abadh Assam Express
# ...          ...        ...                            ...
# 4019         218      12551              Yprkyq Ac Express
# 4020         219       2651                 Yprkyq Express
# 4021         220       2551                 Yprkyq Express
# 4022         221      12395                Ziyarat Express
# 4023         222      12396                Ziyarat Express
#
#                      Starts
# 0           Hyderabad Decan
# 1                 New Delhi
# 2                 New Delhi
# 3                  Tirupati
# 4     New Tinsukia Junction
# ...                     ...
# 4019    Yesvantpur Junction
# ...

# %%
from matplotlib import pyplot as plt

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Train no.     0
# Train name    0
# Starts        0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
plt.bar(['Train name'],['Starts'])
plt.title('student sytem')
plt.ylabel('student ages')
plt.gcf().set_size_iches(6,6)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1384/81530911.py in <module>
#       2 plt.title('student sytem')
#       3 plt.ylabel('student ages')
# ----> 4 plt.gcf().set_size_iches(6,6)
#       5 plt.xticks(rotation=90)
#       6 plt.show()
#
# AttributeError: 'Figure' object has no attribute 'set_size_iches'

# %%
i=display(data[data.Starts =='New Delhi'])
i
# Out:
#       Unnamed: 0  Train no.              Train name     Starts
# 1              1      22416  Andhra Pradesh Express  New Delhi
# 2              2      12724  Andhra Pradesh Express  New Delhi
# 35            35      12958         Adi Sj Rajdhani  New Delhi
# 113          113      12015          Ajmer Shatabdi  New Delhi
# 131          131      12276     Ald Duronto Express  New Delhi
# ...          ...        ...                     ...        ...
# 3615         781      12562    Swatantrta S Express  New Delhi
# 3626         792      12622      Tamil Nadu Express  New Delhi
# 3808           7      12057         Uhl Janshatabdi  New Delhi
# 3839          38      12445          Uttar S Kranti  New Delhi
# 3848          47      12554        Vaishali Express  New Delhi
#
# [120 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4024 non-null   int64
#  1   Train no.   4024 non-null   int64
#  2   Train name  4024 non-null   object
#  3   Starts      4024 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 125.9+ KB

# %%
data.dtypes
# Out:
# Unnamed: 0     int64
# Train no.      int64
# Train name    object
# Starts        object
# dtype: object

# %%
data.describe()
# Out:
#         Unnamed: 0     Train no.
# count  4024.000000   4024.000000
# mean    454.616302  14655.801690
# std     279.980977  11555.820993
# min       0.000000    111.000000
# 25%     201.000000   8620.250000
# 50%     447.000000  12720.500000
# 75%     698.000000  17210.250000
# max     966.000000  99734.000000

# %%
data.corr()
# Out:
#             Unnamed: 0  Train no.
# Unnamed: 0    1.000000   0.018137
# Train no.     0.018137   1.000000

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# Train no.     0
# Train name    0
# Starts        0
# dtype: int64

# %%
data.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0  Train no.                     Train name  \
# 0              0      12723         Andhra Pradesh Express
# 1              1      22416         Andhra Pradesh Express
# 2              2      12724         Andhra Pradesh Express
# 3              3      12707  Andhra Pradesh Sampark Kranti
# 4              4      15909            Abadh Assam Express
# ...          ...        ...                            ...
# 4019         218      12551              Yprkyq Ac Express
# 4020         219       2651                 Yprkyq Express
# 4021         220       2551                 Yprkyq Express
# 4022         221      12395                Ziyarat Express
# 4023         222      12396                Ziyarat Express
#
#                      Starts
# 0           Hyderabad Decan
# 1                 New Delhi
# 2                 New Delhi
# 3                  Tirupati
# 4     New Tinsukia Junction
# ...                     ...
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of       Unnamed: 0  Train no.                     Train name  \
# 0              0      12723         Andhra Pradesh Express
# 1              1      22416         Andhra Pradesh Express
# 2              2      12724         Andhra Pradesh Express
# 3              3      12707  Andhra Pradesh Sampark Kranti
# 4              4      15909            Abadh Assam Express
# ...          ...        ...                            ...
# 4019         218      12551              Yprkyq Ac Express
# 4020         219       2651                 Yprkyq Express
# 4021         220       2551                 Yprkyq Express
# 4022         221      12395                Ziyarat Express
# 4023         222      12396                Ziyarat Express
#
#                      Starts
# 0           Hyderabad Decan
# 1                 New Delhi
# 2                 New Delhi
# 3                  Tirupati
# 4     New Tinsukia Junction
# ...                     ...
# ...
